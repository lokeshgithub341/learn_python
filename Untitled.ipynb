# %%
food = '120.34'
rent = '500.67'

total = food + rent

print(total)
# Out:
# 120.34500.67

# %%
type(food)
# Out:
# float

# %%
id(food)
# Out:
# 2510944241904

# %%
food = 120.34
rent = 500.67

total = food + rent

print(total)
# Out:
# 621.01

# %%
type(food)
# Out:
# float

# %%
id(food)
# Out:
# 2510944241904

# %%
food = '120.34'
print(type(food))
print(id(food))

food = 120.34
print(type(food))
print(id(food))
# Out:
# <class 'str'>
# 2510950449584
# <class 'float'>
# 2510950123376

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
vegatables = ('ladies', 'finger', 'bringol')
fruits = ('apple', 'banana', 'pinaple', 'kiwi')
print(f"I eat {vegatables} vegatables and {fruits} fruits daily.")
# Out:
# I eat ('ladies', 'finger', 'bringol') vegatables and ('apple', 'banana', 'pinaple', 'kiwi') fruits daily.

# %%
Print ‘The Himalayas’ using slice operator
Print “mountain range” using a negative index
Print “The Himalayas on the planet” using slice as well as f-string

# %%
var1 = 'The Himalayas are one of the youngest mountain ranges on the planet'
print(var1)
# Out:
# The Himalayas are one of the youngest mountain ranges on the planet

# %%
print(len(var1))
# Out:
# 67

# %%
print(var1[0:13])
# Out:
# The Himalayas

# %%
position = var1.find("mountain range")
print(position)
# Out:
# 38

# %%
print(var1[-29:-16])
# Out:
# mountain rang

# %%
first_part = var1[:14]
last_part = var1[-13:]

print(first_part + last_part)
# Out:
# The Himalayas on the planet

# %%
variabl = ("There are 9 planet in the solar system")
print(variabl)
# Out:
# There are 9 planet in the solar system

# %%
variabl = variabl.replace('9','8')
print(variabl)
# Out:
# There are 8 planet in the solar system

# %%
variabl = variabl.replace('planet','planets')
print(variabl)
# Out:
# There are 8 planets in the solar system

# %%
s = "12345a"
print(s.isdigit())
# Out:
# False

# %%
word = "Python"
print("PyT" in word)
# Out:
# False

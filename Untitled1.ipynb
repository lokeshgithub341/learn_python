# %%
items = ['bread','pasta','fruits','veggies']
print(items)
# Out:
# ['bread', 'pasta', 'fruits', 'veggies']

# %%
print(items[-1])
# Out:
# veggies

# %%
items.append('butter')

# %%
print(items)
# Out:
# ['bread', 'pasta', 'fruits', 'veggies', 'butter']

# %%
items.remove('butter')
print(items)
# Out:
# ['bread', 'pasta', 'fruits', 'veggies']

# %%
items.insert(1,'butter')
print(items)
# Out:
# ['bread', 'butter', 'pasta', 'fruits', 'veggies']

# %%
items[1] = 'chese'
items
# Out:
# ['bread', 'chese', 'pasta', 'fruits', 'veggies']

# %%
items[3:] = ['cashews']
items
# Out:
# ['bread', 'chese', 'pasta', 'cashews']

# %%
print(items)
# Out:
# ['bread', 'chese', 'pasta', 'cashews']

# %%
'rice' in items
# Out:
# False

# %%
'cashews' in items
# Out:
# True

# %%
expencess = [30,1200,45,3000]
expencess.sort()
expencess
# Out:
# [30, 45, 1200, 3000]

# %%
expencess = [30,1200,45,3000]
expencess.sort(reverse = True)
expencess
# Out:
# [3000, 1200, 45, 30]

# %%
food_items = ['bread','pasta','fruits']
bathroom_items = ['soap','bath cleaning liquid']
itemss = food_items + bathroom_items
itemss
# Out:
# ['bread', 'pasta', 'fruits', 'soap', 'bath cleaning liquid']

# %%
ites = ('bread', 'milk', 'eggs')
print(ites)
# Out:
# ('bread', 'milk', 'eggs')

# %%
print(ites[1])
# Out:
# milk

# %%
items[1] = 'cheese'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 items[1] = 'cheese'
#
# TypeError: 'tuple' object does not support item assignment
